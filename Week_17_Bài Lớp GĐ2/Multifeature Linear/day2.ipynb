# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('used_cars.csv')

# %%
df.columns
# Out:
# Index(['brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
#        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title',
#        'price'],
#       dtype='object')

# %%
X = df[['brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
       'transmission', 'ext_col', 'int_col']]

# %%
y= df['price']

# %%
X["car_age"] = 2025 - X["model_year"]+1
X["car_age"].head(5)
# Out:
# C:\Users\Learning\AppData\Local\Temp\ipykernel_13668\2088291213.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["car_age"] = 2025 - X["model_year"]+1
# 0    13
# 1     5
# 2     4
# 3    11
# 4     5
# Name: car_age, dtype: int64

# %%
X= X.drop("model_year",axis=1)

# %%
X
# Out:
#          brand                            model      milage      fuel_type  \
# 0         Ford  Utility Police Interceptor Base  51,000 mi.  E85 Flex Fuel
# 1      Hyundai                     Palisade SEL  34,742 mi.       Gasoline
# 2        Lexus                    RX 350 RX 350  22,372 mi.       Gasoline
# 3     INFINITI                 Q50 Hybrid Sport  88,900 mi.         Hybrid
# 4         Audi        Q3 45 S line Premium Plus   9,835 mi.       Gasoline
# ...        ...                              ...         ...            ...
# 4004   Bentley             Continental GT Speed     714 mi.       Gasoline
# 4005      Audi             S4 3.0T Premium Plus  10,900 mi.       Gasoline
# 4006   Porsche                           Taycan   2,116 mi.            NaN
# 4007      Ford                     F-150 Raptor  33,000 mi.       Gasoline
# 4008       BMW                     X3 xDrive30i  43,000 mi.       Gasoline
#
#                                                  engine  \
# 0     300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1                                  3.8L V6 24V GDI DOHC
# 2                                        3.5 Liter DOHC
# 3     354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4                            2.0L I4 16V GDI DOHC Turbo
# ...                                                 ...
# 4004                   6.0L W12 48V PDI DOHC Twin Turbo
# 4005      349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 4006                                           Electric
# 4007      450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 4008       248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                            transmission                 ext_col  int_col  \
# 0                           6-Speed A/T                   Black    Black
# 1                     8-Speed Automatic         Moonlight Cloud     Gray
# 2                             Automatic                    Blue    Black
# 3                           7-Speed A/T                   Black    Black
# 4                     8-Speed Automatic  Glacier White Metallic    Black
# ...                                 ...                     ...      ...
# 4004  8-Speed Automatic with Auto-Shift                   C / C  Hotspur
# 4005     Transmission w/Dual Shift Mode                   Black    Black
# 4006                          Automatic                   Black    Black
# 4007                                A/T                    Blue    Black
# 4008                                A/T                    Gray    Brown
#
#       car_age
# 0          13
# 1           5
# 2           4
# 3          11
# 4           5
# ...       ...
# 4004        3
# 4005        4
# 4006        4
# 4007        6
# 4008        6
#
# [4009 rows x 9 columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   milage        4009 non-null   object
#  3   fuel_type     3839 non-null   object
#  4   engine        4009 non-null   object
#  5   transmission  4009 non-null   object
#  6   ext_col       4009 non-null   object
#  7   int_col       4009 non-null   object
#  8   car_age       4009 non-null   int64
# dtypes: int64(1), object(8)
# memory usage: 282.0+ KB

# %%
X =  X.dropna()
X
# Out:
#               brand                            model      milage  \
# 0              Ford  Utility Police Interceptor Base  51,000 mi.
# 1           Hyundai                     Palisade SEL  34,742 mi.
# 2             Lexus                    RX 350 RX 350  22,372 mi.
# 3          INFINITI                 Q50 Hybrid Sport  88,900 mi.
# 4              Audi        Q3 45 S line Premium Plus   9,835 mi.
# ...             ...                              ...         ...
# 4003  Mercedes-Benz             E-Class E 300 4MATIC  53,705 mi.
# 4004        Bentley             Continental GT Speed     714 mi.
# 4005           Audi             S4 3.0T Premium Plus  10,900 mi.
# 4007           Ford                     F-150 Raptor  33,000 mi.
# 4008            BMW                     X3 xDrive30i  43,000 mi.
#
#           fuel_type                                             engine  \
# 0     E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1          Gasoline                               3.8L V6 24V GDI DOHC
# 2          Gasoline                                     3.5 Liter DOHC
# 3            Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4          Gasoline                         2.0L I4 16V GDI DOHC Turbo
# ...             ...                                                ...
# 4003       Gasoline       241.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 4004       Gasoline                   6.0L W12 48V PDI DOHC Twin Turbo
# 4005       Gasoline      349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 4007       Gasoline      450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 4008       Gasoline       248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                            transmission                 ext_col  int_col  \
# 0                           6-Speed A/T                   Black    Black
# 1                     8-Speed Automatic         Moonlight Cloud     Gray
# 2                             Automatic                    Blue    Black
# 3                           7-Speed A/T                   Black    Black
# 4                     8-Speed Automatic  Glacier White Metallic    Black
# ...                                 ...                     ...      ...
# 4003                                A/T                   Black    Black
# 4004  8-Speed Automatic with Auto-Shift                   C / C  Hotspur
# 4005     Transmission w/Dual Shift Mode                   Black    Black
# 4007                                A/T                    Blue    Black
# 4008                                A/T                    Gray    Brown
#
#       car_age
# 0          13
# 1           5
# 2           4
# 3          11
# 4           5
# ...       ...
# 4003        8
# 4004        3
# 4005        4
# 4007        6
# 4008        6
#
# [3839 rows x 9 columns]

# %%
X['transmission']
# Out:
# 0                             6-Speed A/T
# 1                       8-Speed Automatic
# 2                               Automatic
# 3                             7-Speed A/T
# 4                       8-Speed Automatic
#                       ...
# 4003                                  A/T
# 4004    8-Speed Automatic with Auto-Shift
# 4005       Transmission w/Dual Shift Mode
# 4007                                  A/T
# 4008                                  A/T
# Name: transmission, Length: 3839, dtype: object

# %%
X['transmission'] = X['transmission'].str.extract(r"(\d+)-S").astype(float)
# Out:
# C:\Users\Learning\AppData\Local\Temp\ipykernel_13668\479147629.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['transmission'] = X['transmission'].str.extract(r"(\d+)-S").astype(float)

# %%
X['transmission']
# Out:
# 0       6.0
# 1       8.0
# 2       NaN
# 3       7.0
# 4       8.0
#        ...
# 4003    NaN
# 4004    8.0
# 4005    NaN
# 4007    NaN
# 4008    NaN
# Name: transmission, Length: 3839, dtype: float64

# %%
X=X.drop(['transmission'],axis=1)

# %%
X
# Out:
#               brand                            model      milage  \
# 0              Ford  Utility Police Interceptor Base  51,000 mi.
# 1           Hyundai                     Palisade SEL  34,742 mi.
# 2             Lexus                    RX 350 RX 350  22,372 mi.
# 3          INFINITI                 Q50 Hybrid Sport  88,900 mi.
# 4              Audi        Q3 45 S line Premium Plus   9,835 mi.
# ...             ...                              ...         ...
# 4003  Mercedes-Benz             E-Class E 300 4MATIC  53,705 mi.
# 4004        Bentley             Continental GT Speed     714 mi.
# 4005           Audi             S4 3.0T Premium Plus  10,900 mi.
# 4007           Ford                     F-150 Raptor  33,000 mi.
# 4008            BMW                     X3 xDrive30i  43,000 mi.
#
#           fuel_type                                             engine  \
# 0     E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1          Gasoline                               3.8L V6 24V GDI DOHC
# 2          Gasoline                                     3.5 Liter DOHC
# 3            Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4          Gasoline                         2.0L I4 16V GDI DOHC Turbo
# ...             ...                                                ...
# 4003       Gasoline       241.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 4004       Gasoline                   6.0L W12 48V PDI DOHC Twin Turbo
# 4005       Gasoline      349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 4007       Gasoline      450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 4008       Gasoline       248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      ext_col  int_col  car_age
# 0                      Black    Black       13
# 1            Moonlight Cloud     Gray        5
# 2                       Blue    Black        4
# 3                      Black    Black       11
# 4     Glacier White Metallic    Black        5
# ...                      ...      ...      ...
# 4003                   Black    Black        8
# 4004                   C / C  Hotspur        3
# 4005                   Black    Black        4
# 4007                    Blue    Black        6
# 4008                    Gray    Brown        6
#
# [3839 rows x 8 columns]

# %%
for col in ["brand","model","fuel_type","ext_col","int_col"]:
    unique_values = df[col].unique()
    label_2_idx = {label:idx for idx, label in enumerate(unique_values)}


    X[col] = X[col].map(label_2_idx)

# %%
X
# Out:
#       brand  model      milage  fuel_type  \
# 0         0      0  51,000 mi.          0
# 1         1      1  34,742 mi.          1
# 2         2      2  22,372 mi.          1
# 3         3      3  88,900 mi.          2
# 4         4      4   9,835 mi.          1
# ...     ...    ...         ...        ...
# 4003     13    775  53,705 mi.          1
# 4004     20    695     714 mi.          1
# 4005      4   1094  10,900 mi.          1
# 4007      0   1081  33,000 mi.          1
# 4008      6    326  43,000 mi.          1
#
#                                                  engine  ext_col  int_col  \
# 0     300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...        0        0
# 1                                  3.8L V6 24V GDI DOHC        1        1
# 2                                        3.5 Liter DOHC        2        0
# 3     354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...        0        0
# 4                            2.0L I4 16V GDI DOHC Turbo        3        0
# ...                                                 ...      ...      ...
# 4003       241.0HP 2.0L 4 Cylinder Engine Gasoline Fuel        0        0
# 4004                   6.0L W12 48V PDI DOHC Twin Turbo      318       35
# 4005      349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel        0        0
# 4007      450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel        2        0
# 4008       248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel        9        5
#
#       car_age
# 0          13
# 1           5
# 2           4
# 3          11
# 4           5
# ...       ...
# 4003        8
# 4004        3
# 4005        4
# 4007        6
# 4008        6
#
# [3839 rows x 8 columns]

# %%
X['milage'] = X['milage'].str[0:-3]
X['milage'] = X['milage'].str.replace(",", "").astype(int)

#ví dụ 43000 mi. thì -3 ỡ m nên cắt đi

# %%
X['engine']=X['engine'].str.extract(r"(\d+.\d+)L").astype(float) #regular expression

# %%
X
# Out:
#       brand  model  milage  fuel_type  engine  ext_col  int_col  car_age
# 0         0      0   51000          0     3.7        0        0       13
# 1         1      1   34742          1     3.8        1        1        5
# 2         2      2   22372          1     NaN        2        0        4
# 3         3      3   88900          2     3.5        0        0       11
# 4         4      4    9835          1     2.0        3        0        5
# ...     ...    ...     ...        ...     ...      ...      ...      ...
# 4003     13    775   53705          1     2.0        0        0        8
# 4004     20    695     714          1     6.0      318       35        3
# 4005      4   1094   10900          1     3.0        0        0        4
# 4007      0   1081   33000          1     3.5        2        0        6
# 4008      6    326   43000          1     2.0        9        5        6
#
# [3839 rows x 8 columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3839 entries, 0 to 4008
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   brand      3839 non-null   int64
#  1   model      3839 non-null   int64
#  2   milage     3839 non-null   int32
#  3   fuel_type  3839 non-null   int64
#  4   engine     3606 non-null   float64
#  5   ext_col    3839 non-null   int64
#  6   int_col    3839 non-null   int64
#  7   car_age    3839 non-null   int64
# dtypes: float64(1), int32(1), int64(6)
# memory usage: 254.9 KB

# %%
X_normalized = (X-X.min())/(X.max()- X.min())

# %%
X_normalized
# Out:
#          brand     model    milage  fuel_type    engine   ext_col   int_col  \
# 0     0.000000  0.000000  0.125710   0.000000  0.364865  0.000000  0.000000
# 1     0.017857  0.000527  0.085557   0.142857  0.378378  0.003145  0.006452
# 2     0.035714  0.001055  0.055006   0.142857       NaN  0.006289  0.000000
# 3     0.053571  0.001582  0.219313   0.285714  0.337838  0.000000  0.000000
# 4     0.071429  0.002110  0.024043   0.142857  0.135135  0.009434  0.000000
# ...        ...       ...       ...        ...       ...       ...       ...
# 4003  0.232143  0.408755  0.132391   0.142857  0.135135  0.000000  0.000000
# 4004  0.357143  0.366561  0.001516   0.142857  0.675676  1.000000  0.225806
# 4005  0.071429  0.577004  0.026673   0.142857  0.270270  0.000000  0.000000
# 4007  0.000000  0.570148  0.081255   0.142857  0.337838  0.006289  0.000000
# 4008  0.107143  0.171941  0.105952   0.142857  0.135135  0.028302  0.032258
#
#       car_age
# 0        0.22
# 1        0.06
# 2        0.04
# 3        0.18
# 4        0.06
# ...       ...
# 4003     0.12
# 4004     0.02
# 4005     0.04
# 4007     0.08
# 4008     0.08
#
# [3839 rows x 8 columns]

# %%
y
# Out:
# 0        $10,300
# 1        $38,005
# 2        $54,598
# 3        $15,500
# 4        $34,999
#           ...
# 4004    $349,950
# 4005     $53,900
# 4006     $90,998
# 4007     $62,999
# 4008     $40,000
# Name: price, Length: 4009, dtype: object

# %%
y= y.str[1:]
y= y.str.replace(",", "").astype(int)

# %%
y_normalized = (y - y.min())/(y.max()-y.min())

# %%
y_normalized
# Out:
# 0       0.002812
# 1       0.012196
# 2       0.017817
# 3       0.004573
# 4       0.011178
#           ...
# 4004    0.117866
# 4005    0.017581
# 4006    0.030148
# 4007    0.020663
# 4008    0.012872
# Name: price, Length: 4009, dtype: float64

# %%
TRAIN_RATIO = 0.8
TEST_RATIO = 0.2

# %%
X_train = X_normalized[:int(TRAIN_RATIO * len(X_normalized))]
X_test = X_normalized[int(TRAIN_RATIO * len(X_normalized)):]
y_train = y_normalized[:int(TRAIN_RATIO * len(y_normalized))]
y_test = y_normalized[int(TRAIN_RATIO * len(y_normalized)):]

# %%
train_examples = list(zip(X_train.values, y_train.values))
test_examples = list(zip(X_test.values, y_test.values))
