# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image= cv2.imread('/content/nature.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x500>

# %%
brightened_image= cv2.convertScaleAbs(image, alpha=2.0, beta=50)
cv2_imshow(brightened_image)
cv2.imwrite('brightened_image.jpg', brightened_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x500>
# True

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.array([-4,3,8,300,7])
print(data)
#function of np.clip
data= np.clip(data,0,255)
print(data)
# Out:
# [ -4   3   8 300   7]
# [  0   3   8 255   7]

# %%
def increse_brightness_customize(image_path, birghtness_value , output_path):
  #step 1:Read image
  image= cv2.imread('/content/nature.jpg',cv2.IMREAD_GRAYSCALE)
  #step 2 convert the image to the 1D list
  flattened_image = image.flatten()
  #step 3 Increse brightness and ensure pixel values are between 0 and 255
  brightened_1d = []
  for pixel_value in flattened_image:
    brightened_pixel = pixel_value + brighteness_value
    brightende_1d.append(np.clip(brightened_pixel,0,255))
  #step 4 reshape the 1D list back to the origanal grayscale image scale
  brightened_image = np.array(brightened_1d).reshape(image.shape)
  #step 5 save the image
  cv2.imwrite(output_path, brightened_image)
  return brightened_image
  cv2.imshow(image)
