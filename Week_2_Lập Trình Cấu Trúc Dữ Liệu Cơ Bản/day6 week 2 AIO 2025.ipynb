# %%
data= list(range(1,11))

# %%
print(data[0:5])
# Out:
# [1, 2, 3, 4, 5]

# %%
odd=[]
for num in data:
    if num % 2 != 0:
        odd.append(num)
print(odd)
# Out:
# [1, 3, 5, 7, 9]

# %%
total=0
for num in data:
  total +=num
print(total)
# Out:
# 55
