# %%
pip install numpy matplotlib opencv-python

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
import numpy as np
#tạo 2 array 1D
arr1 = np.array([2,3,4,5,7,8,9])
arr2 = np.array([5,5,7,6,8,8,6])
arr3 = np.array([1,2,3,5,6,7,8])
#stack các array
stacked_arr = np.stack((arr1 , arr2), axis=1)

print("Array đã stack :\n" ,stacked_arr)
# Out:
# Array đã stack :
#  [[2 5]
#  [3 5]
#  [4 7]
#  [5 6]
#  [7 8]
#  [8 8]
#  [9 6]]

# %%
matrix1 = np.array([[1,2],[3,4]])
matrix2 = np.array([[5,6],[7,8]])

print(matrix1 + matrix2)
# Out:
# [[ 6  8]
#  [10 12]]

# %%
matrix1 = [[1,2],[3,4]]
matrix2 = [[5,6],[7,8]]

print(matrix1 + matrix2)
# Out:
# [[1, 2], [3, 4], [5, 6], [7, 8]]

# %%
import numpy as np

array = np.array([1,2,3,4,5,6])
result = np.where(array > 3 , "A" , "B")

print(result)
# Out:
# ['B' 'B' 'B' 'A' 'A' 'A']

# %%
import cv2
import numpy as np

bg_image1 = cv2.imread('background1.jpg',0)
bg_image2 = cv2.imread('object.png', 0)

bg_image1 = cv2.resize(bg_image1, (640,480))
bg_image2 = cv2.resize(bg_image2, (640,480))

bg_image = cv2.cvtColor(bg_image1 , cv2.COLOR_BGR2GRAY)
ob_image = cv2.cvtColor(bg_image2 , cv2.COLOR_BGR2GRAY)

output_image = replaceBackGround ( bg_image1 , bg_image2 , ob_image )

2 plt.imshow ( output_image )
# Out:
#   File "<ipython-input-8-7def0ad5c7ab>", line 15
#     2 plt.imshow ( output_image )
#       ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
def func(x):
    return x**2

def derivative(x):
    return 2*x
lr = 0.1
#x0 = 70
x=70
print(x)
#x1 = x0 - lr * derivative(x0)
#print(x0,x1)
for _ in range(30):
    x = x - lr * derivative(x)
    print(x,func(x))
# Out:
# 70
# 56.0 3136.0
# 44.8 2007.0399999999997
# 35.839999999999996 1284.5055999999997
# 28.671999999999997 822.0835839999999
# 22.937599999999996 526.1334937599999
# 18.35008 336.72543600639995
# 14.680063999999998 215.50427904409594
# 11.744051199999998 137.9227385882214
# 9.395240959999999 88.2705526964617
# 7.516192767999999 56.49315372573549
# 6.012954214399999 36.155618384470706
# 4.810363371519999 23.139595766061255
# 3.8482906972159996 14.809341290279205
# 3.0786325577727998 9.47797842577869
# 2.4629060462182397 6.065906192498362
# 1.9703248369745918 3.882179963198952
# 1.5762598695796735 2.4845951764473293
# 1.2610078956637387 1.5901409129262905
# 1.008806316530991 1.017690184272826
# 0.8070450532247928 0.6513217179346087
# 0.6456360425798342 0.4168458994781495
# 0.5165088340638674 0.2667813756660157
# 0.4132070672510939 0.17074008042625005
# 0.3305656538008751 0.1092736514728
# 0.2644525230407001 0.06993513694259201
# 0.2115620184325601 0.0447584876432589
# ...

# %%
def func(x,y):
    return x**2 + y**2

def derivative(x,y):
    return 2*x , 2*y

lr=0.1
x=  6.0
y=  9.0
print(x,y)
for _ in range (1):
    df_dx,df_dy = derivative(x,y)
    x = x - lr * df_dx
    y = y - lr * df_dy
print(x,y,func(x,y))
# Out:
# 6.0 9.0
# 4.8 7.2 74.88
