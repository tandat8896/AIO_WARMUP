# %%
def find_squared(a):
  epsilon=0.0001
  if a<0:
    print("Squared root of negative number is invalid")
    return none
  if a==0:
    return 0
  if a>0:
    base=0
    update=a
    cache=[a]
    while abs(update - base) >= epsilon:
      base=update
      update= base - ((base**2 -a) /(2*update))
      cache.append(update)
    return cache
find_squared(2)
# Out:
# [2, 1.5, 1.4166666666666667, 1.4142156862745099, 1.4142135623746899]
